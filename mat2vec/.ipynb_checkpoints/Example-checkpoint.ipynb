# %%
from gensim.models import Word2Vec
w2v_model = Word2Vec.load("training/models/pretrained_embeddings")

# %%
words = w2v_model.wv.most_similar(positive = ["high-Tc_superconductor"], 
                                  topn = 5000)

# %%
words[1:100]
# Out:
# [('high-T_c_superconductor', 0.8274821043014526),
#  ('high-Tc_superconductors', 0.8188086748123169),
#  ('superconductor', 0.8011067509651184),
#  ('superconductors', 0.7967555522918701),
#  ('YBa2Cu3O7−δ', 0.7961038947105408),
#  ('HTSC', 0.7949869632720947),
#  ('high-T_c_superconductors', 0.7854158878326416),
#  ('high-Tc_superconducting', 0.7766953706741333),
#  ('superconducting', 0.7754950523376465),
#  ('high-T_c', 0.7748551964759827),
#  ('Bi2CaCu2O8Sr2', 0.768642783164978),
#  ('Ba2Cu3O7Y', 0.7671619653701782),
#  ('BaCuOY', 0.7612648010253906),
#  ('BSCCO', 0.7556466460227966),
#  ('Ba2CaCu2O8Tl2', 0.7530843615531921),
#  ('YBa2Cu3O7−x', 0.7429651021957397),
#  ('T_c_superconductors', 0.7414703369140625),
#  ('YBa2Cu3Ox', 0.737498939037323),
#  ('cuprate_superconductor', 0.7371646165847778),
#  ('Bi2Sr2CaCu2O8+x', 0.7345929145812988),
#  ('Bi2Sr2CaCu2O8+δ', 0.7344222664833069),
#  ('superconductive', 0.7280788421630859),
#  ('Y-Ba-Cu-O', 0.7256162166595459),
#  ('YBa2Cu3O7-δ', 0.7253754734992981),
#  ('T_c_superconductor', 0.720426619052887),
#  ('Ba2Ca2Cu3O10Tl2', 0.7189056873321533),
#  ('cuprate', 0.7124019265174866),
#  ('YBCO', 0.7103877067565918),
#  ('YBa2Cu3Oy', 0.7100633382797241),
#  ('high-T_c_superconducting', 0.7096511721611023),
#  ('Ba2Cu4O8Y', 0.7006592750549316),
#  ('Ba2Cu3OY', 0.6999704837799072),
#  ('superconductor_YBa2Cu3O7−δ', 0.6980488300323486),
#  ('Bi2Ca2CuO8Sr2', 0.6947749853134155),
#  ('HTSCs', 0.693466067314148),
#  ('bi2212', 0.6906123161315918),
#  ('Cu20La37O80Sr3', 0.6886947751045227),
#  ('Y\ue5f8Ba\ue5f8Cu\ue5f8O', 0.6886686086654663),
#  ('superconducting_state', 0.6860836148262024),
#  ('bi-based_high-Tc', 0.6854851245880127),
#  ('o7−δ', 0.6844527721405029),
#  ('high-Tc_superconducting_oxides', 0.6843304634094238),
#  ('Ag3Ba20Cu27Y10', 0.6832818984985352),
#  ('Tl2Ba2CuO6+δ', 0.6827547550201416),
#  ('-superconductors', 0.6809815168380737),
#  ('Tl2Ba2Ca2Cu3O10−δ', 0.6809303760528564),
#  ('HgBa2CuO4+x', 0.6794165372848511),
#  ('La2−xSrxCuO4', 0.6777715682983398),
#  ('GdBa2Cu3O7-δ', 0.6761534214019775),
#  ('As20Fe20O17Sm20', 0.6761081218719482),
#  ('BaBiOPb', 0.675774335861206),
#  ('YBCO_superconductor', 0.6755242347717285),
#  ('cuprates', 0.6751278042793274),
#  ('superconducting_cuprate', 0.6745951175689697),
#  ('bi-2212', 0.6726449131965637),
#  ('BiCaCuOSr', 0.6724215745925903),
#  ('High-Tc', 0.6721548438072205),
#  ('Bi2Sr2Ca1Cu2O8+δ', 0.6717148423194885),
#  ('YBa2Cu3O7-x', 0.6713055372238159),
#  ('Bi2Sr2Ca2Cu3O10+x', 0.6712583303451538),
#  ('Ba2Cu3O7Yb', 0.6702959537506104),
#  ('Cu5La9O20Sr', 0.6692959070205688),
#  ('Bi-Sr-Ca-Cu-O', 0.6686236262321472),
#  ('Bi2Sr2CaCu2Oy', 0.6677700281143188),
#  ('2212', 0.6669328212738037),
#  ('Tl-Ba-Ca-Cu-O', 0.6660221815109253),
#  ('high-TC_superconductor', 0.6659460663795471),
#  ('CaLaBaCu3O7−y', 0.6651531457901001),
#  ('non-superconducting', 0.6649128794670105),
#  ('La-Ba-Cu-O', 0.6634587049484253),
#  ('BaCaCuHgO', 0.6630492210388184),
#  ('non-cuprate', 0.6626361608505249),
#  ('optimally_doped', 0.6625948548316956),
#  ('Ba3Cu20La37O80', 0.6625537276268005),
#  ('Bi2CaCu2OSr2', 0.6620253324508667),
#  ('High-T_c', 0.6611955761909485),
#  ('normal_state', 0.6605919003486633),
#  ('CuLaOSr', 0.6605607271194458),
#  ('superconducting_YBa2Cu3O7−δ', 0.660313606262207),
#  ('Ba8Cu12LuO28Y3', 0.6599234342575073),
#  ('Ba3Bi5K2O15', 0.6597955226898193),
#  ('Cr3Cu10Hg7O40Sr20', 0.659509539604187),
#  ('YBCO_superconductors', 0.6591991186141968),
#  ('Bi2CaCu2Sr2', 0.6591170430183411),
#  ('Ce3Cu20Nd37O80', 0.6583959460258484),
#  ('Bi2Sr2CaCu2O8+δ_single_crystals', 0.6582524180412292),
#  ('Bi2Ca2Cu3O10Sr2', 0.6580333113670349),
#  ('cuprate_superconductors', 0.65739905834198),
#  ('YBa2Cu3O7−y', 0.6568422317504883),
#  ('high-Tc_oxides', 0.6563466787338257),
#  ('Ba2Ca2Cu3HgO8', 0.6556044816970825),
#  ('BiCaCu3O8Sr', 0.6554579138755798),
#  ('Y-123', 0.6552293300628662),
#  ('vortex_matter_phase_diagram', 0.6548240780830383),
#  ('Tc', 0.6547789573669434),
#  ('BSCCO(2212)', 0.6541479229927063),
#  ('HighTc', 0.6540340781211853),
#  ('High-Tc_superconductors', 0.6538677215576172),
#  ('BaBiPbSr', 0.6523765325546265)]

# %%
ELEMENTS = ["H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "Ar", "K",
            "Ca", "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Kr",
            "Rb", "Sr", "Y", "Zr", "Nb", "Mo", "Tc", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I",
            "Xe", "Cs", "Ba", "La", "Ce", "Pr", "Nd", "Pm", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb",
            "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au", "Hg", "Tl", "Pb", "Bi", "Po", "At", "Rn", "Fr",
            "Ra", "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", "Cm", "Bk", "Cf", "Es", "Fm", "Md", "No", "Lr", "Rf",
            "Db", "Sg", "Bh", "Hs", "Mt", "Ds", "Rg", "Cn", "Nh", "Fl", "Mc", "Lv", "Ts", "Og"]

# %%
def is_formula(formula):
        N = len(formula)
        i = 0
        while i < N:
            if formula[i].isupper():
                if i < N - 1 and formula[i+1].islower and str(formula[i]+formula[i+1]) in ELEMENTS:
                    if i < N-2 and formula[i+2].isdigit():
                        i += 3
                    else:
                        i += 2
                elif formula[i] in ELEMENTS:
                    if i < N - 1 and formula[i+1].isdigit():
                        
                        i += 2
                    else:
                        
                        i += 1
                else:
                    return False
            else:
                return False  
            
        return True
    
    
def atom_list(formula):
        N = len(formula)
        atoms = []
        i = 0
        for i in range(N):
            if formula[i].isupper():
                if i < N - 1 and formula[i+1].islower and str(formula[i]+formula[i+1]) in ELEMENTS:
                    atoms.append(str(formula[i]+formula[i+1]))
                elif formula[i] in ELEMENTS:
                    atoms.append(formula[i])
                
        return atoms

# %%
candidates = []
atom_lists = []
for word in list(zip(*words))[0]:
    if is_formula(word):
        atoms = atom_list(word)
        if atoms not in atom_lists:
            candidates.append(word)
            atom_lists.append(atoms)

# %%
len(candidates)
# Out:
# 1015

# %%
candidates[1:300]
# Out:
# ['Ba2Cu3O7Y',
#  'BSCCO',
#  'Ba2CaCu2O8Tl2',
#  'YBCO',
#  'BaBiOPb',
#  'Ba2Cu3O7Yb',
#  'BaCaCuHgO',
#  'CuLaOSr',
#  'Bi2CaCu2Sr2',
#  'Tc',
#  'BaBiPbSr',
#  'BaBiKO',
#  'Ba2Cu4Ho',
#  'Bi2CaO8Sr2',
#  'HBCCO',
#  'Ba2Cu4ErO8',
#  'Bi2LaPb2Sr',
#  'NCCO',
#  'BaCaCuOY',
#  'BaCuLaOSr',
#  'Ba2CuO6Tl2',
#  'Ba2Cu3EuO7',
#  'Bi2CaCu2IO8Sr2',
#  'Ba2Cu3HoO7',
#  'BaCuLaO',
#  'BBi2C2CaCu2O2SSr2',
#  'Bi2Cu2O8Sr2Y',
#  'BaCu3O7SrY',
#  'BPSCCO',
#  'Ba2Cu3O7Pr',
#  'B2CNi2Y',
#  'BiCaCuPbSr',
#  'CuO4',
#  'BaTl',
#  'Ba2Cu2O7TlY',
#  'As3Cr3K2',
#  'Ba2Cu3GdO7',
#  'BaCaCuFHgO',
#  'Ba2Y',
#  'Ba2Nd',
#  'BaCuY',
#  'Ba2Cu3O7Sm',
#  'Ba2Hg',
#  'As3Cr3Rb2',
#  'Ba2Cu3DyO7',
#  'BiCaCuOPbSnSr',
#  'CuLaNdOSr',
#  'Ba2CaTl2',
#  'BCOY',
#  'Ba2CuHgO4',
#  'BISCCO',
#  'Ba2Ca2Cu3Tl2',
#  'BC2O8S',
#  'Bi2CuO6Sr2',
#  'Ba3Sr2Tl5',
#  'Ba2Pr',
#  'Bi2FNd2OS4',
#  'BiCaCuOPbSr',
#  'As5Fe5O3Sm5',
#  'FeSeTe',
#  'LaMo6Se8',
#  'B2RuY',
#  'BCSCO',
#  'CaCuO8',
#  'YBKCO',
#  'As5FFe5O4Pr5',
#  'AsFFeSm',
#  'Ba2Cu3Nd',
#  'CaCuOSr',
#  'O4RuSr2',
#  'Ba2Cu3O7',
#  'Ba2CaCu2O8Sr2',
#  'BaPb',
#  'Pb2Sr',
#  'B2Cu3O7Y',
#  'Ge3NiY',
#  'BaGaGe',
#  'Ge2La3Rh2',
#  'Ba2Cu2O7PrTl',
#  'Bi2FOS4',
#  'Ba2CO7U3Y',
#  'Bi2Cu2O8PrSr2',
#  'AsFFeGdO',
#  'EuRuSr2',
#  'BISCO',
#  'Ba2Cu3O7Tm',
#  'CaCuOPbSrTl',
#  'AsLaNiO',
#  'InPb9',
#  'BiC2OS',
#  'AsFeOPr',
#  'B2CPt2Y',
#  'B2CLuNi2',
#  'CaIrSi3',
#  'Ba2Cu',
#  'Cu2LaO6Pb2Sr',
#  'Ba2DyNbO6',
#  'Cu2EuO8RuSr2',
#  'BKBO',
#  'Ba2NbO6Yb',
#  'B3GeN',
#  'BC2OPbS',
#  'Cu3OY',
#  'As5FFe5O4Sm5',
#  'BaGaSi',
#  'CeCoIn',
#  'Nd2Sr5',
#  'CaRhSn',
#  'LaRu3Si2',
#  'Ba2CaO8Tl2',
#  'BaTaY',
#  'GdRu',
#  'CdCe2Co2In9',
#  'Ba2K3',
#  'Ge2Ir2La3',
#  'HgRe',
#  'Ba4Cu6GdO2Sm',
#  'Bi2CaF2LaSe4',
#  'Ba2Ca2Cu3O',
#  'As2Fe2OSr4V2',
#  'Ba2Eu',
#  'CuO5Sr2',
#  'Cu3O8Pb2PrSr2',
#  'Ba2F2O2Pd',
#  'As4Fe4Gd2O2Rb',
#  'CuLa2O4',
#  'As2CsFe2',
#  'BFeS',
#  'Ba2CeCu3O9Y',
#  'Bi2FLa2OSe4',
#  'Ba2Cu3F2OY',
#  'BiCaCuOSrY',
#  'As2Fe2Li',
#  'Pb3Tl',
#  'BiCuSr',
#  'BeU',
#  'Ba2Cu3DyO7Y',
#  'As9Eu5P6',
#  'Bi4O4S3',
#  'B4Rh4Y',
#  'CuO6Sn',
#  'Bi2FOPr2S4',
#  'FeOTe',
#  'CuNd2O4',
#  'BaHo',
#  'As5Fe5O5Pr4Sr',
#  'Ba3CaCu6La2O2',
#  'Bi2CaSr2',
#  'PbSe2Ta',
#  'AlAuU',
#  'Ba2Cu3IO6Y',
#  'Bi2Sr2Y',
#  'Ba2CaHg',
#  'BRh4Si2Y',
#  'AsCoLi',
#  'CoGaPu',
#  'LaPd2Sb2',
#  'B2N3Ni2Th3',
#  'DyMo6S8',
#  'BLuRh4Si2',
#  'Ba2Co2CuLaO8',
#  'BaLa2NbO6',
#  'CuSr2',
#  'Bi2Ce2FOS4',
#  'Cu2GdO8RuSr2',
#  'Pd2Th',
#  'BaCu3La',
#  'In5PuRh',
#  'AsFFeLaO',
#  'AsFeNTh',
#  'BiNdOS2',
#  'B2LuNi2',
#  'BSCC',
#  'BCCaLaOPr',
#  'BBaCuNdO5',
#  'HoMo6S8',
#  'NiO3PScSr2',
#  'LaRu8Si8U3',
#  'Cs2Fe5Se5',
#  'Cu2O8RuSr2Y',
#  'Bi2LaO2S4Th',
#  'C2CuNO5',
#  'Ba2C3O7Y',
#  'Ga4HfV2',
#  'B2Mg',
#  'Fe5K2Se5',
#  'KO6Os2',
#  'B3CLi2',
#  'MnOTm',
#  'Ba2Tm',
#  'AlCe5Fe9',
#  'As2Ni2Sr',
#  'Ca2CuPb3Sr8Y2',
#  'BPBO',
#  'Bi2Ca2Cu3F4O8Sr2',
#  'Ge3Nb7',
#  'Er2Fe3Si5',
#  'B2CLaPt2',
#  'Ce5Gd',
#  'BiF2S2',
#  'Bi7Ca8PbSr8',
#  'NdYb9',
#  'BaCaCu',
#  'Ba2Cu3NdO7',
#  'BaCaCuLa',
#  'CLaOS',
#  'B8C4Ho3Ni8Y',
#  'B2CErNi2',
#  'CeFeOP',
#  'Ge2Pd2Sr',
#  'Ba2HoNbO6',
#  'BaCuErLaO',
#  'Ca9Ce',
#  'As5BaF2Fe5Nd4O3',
#  'Cu3O8Pb2Sr2Y',
#  'Nb2PdS5',
#  'BCDyOY',
#  'B4NdRh4',
#  'BSCYCO',
#  'Pd2SbU',
#  'Ba2Sb6Sn3',
#  'B2CHoNi2',
#  'BC2OTl',
#  'Mo6S8Yb',
#  'As4Ba2Cr2OTi2',
#  'CoYb',
#  'ClCuH3O3Sr',
#  'CeGe3Ni',
#  'CeIn5',
#  'GaGeSr',
#  'BiS2',
#  'B4LuRu4',
#  'As2CuPr',
#  'Cu3Rh3S8',
#  'F3Tl',
#  'As2EuFe',
#  'As2LaPd2',
#  'AsNiO3ScSr2',
#  'Ce2In8Ir',
#  'CeCuNdO',
#  'EuFe',
#  'PrSr2',
#  'La3Tl',
#  'As4BaFe4K',
#  'Fe2Se',
#  'CeHg',
#  'CsFeS',
#  'KOs',
#  'AlCu2La6Ni',
#  'Cl2Cu3O4Sr2',
#  'HeTc',
#  'CaPtSi3',
#  'O4S3',
#  'Ba2C7Cu3Y',
#  'HfNbTi',
#  'Ag2CGe2',
#  'CoLa2',
#  'CaCu2La2O7',
#  'Co3Y4',
#  'YPBCO',
#  'CoO5Sr2Ti',
#  'CoLa2NiO8Sr2',
#  'La3Ni4O2P4',
#  'Ba5Bi3La2',
#  'CsO6Os2',
#  'Gd7NiPd2',
#  'B2CLaNi2',
#  'OsRb',
#  'LaRhSi3',
#  'As5FFe5Nd5O4',
#  'GaNi4Tb',
#  'As5CaFePt2',
#  'PdPu',
#  'LaNiO4',
#  'Pb3S',
#  'MgPtSi',
#  'CeCu2Si2',
#  'RuZr3',
#  'CeCuOPr',
#  'Ce3Ge2Rh2',
#  'O3P2V2',
#  'FISC',
#  'Nd2O4Pd',
#  'B2CPd2Y',
#  'P2Pd2Y',
#  'Er2Mn2O7',
#  'Ba2Cu3Sm',
#  'BCCaOY',
#  'BCErOY',
#  'PrSb2',
#  'Cd2O7Re2',
#  'Sr2Y',
#  'AlEu2O6Ta',
#  'Ba4CuFeGd2O',
#  'H2NaPd3',
#  'CuNdO2Sr',
#  'Ge3Ni',
#  'B2GeTa5',
#  'GdTe3']

# %%
model = Word2Vec.load("training/tmp/arxiv_abstracts_epoch29.model")

# %%
words = model.wv.most_similar(positive = ["high-Tc", "high-Tc_superconductor", "HTSC"], topn = 5000)

# %%
candidates = []
atom_lists = []
for word in list(zip(*words))[0]:
    if is_formula(word):
        atoms = atom_list(word)
        if atoms not in atom_lists:
            candidates.append(word)
            atom_lists.append(atoms)

# %%
len(candidates)
# Out:
# 137

# %%
candidates
# Out:
# ['LaFeAsO',
#  'FeS',
#  'KFe2Se2',
#  'CeCoIn5',
#  'LaOFeAs',
#  'SrFe2As2',
#  'CaFeAsF',
#  'HF',
#  'SrFeAsF',
#  'KFe2As2',
#  'BaFe2As2',
#  'Ir',
#  'Eu',
#  'LiFeAs',
#  'NaFeAs',
#  'SrPt2As2',
#  'URhGe',
#  'CaC6',
#  'BiPd',
#  'H3S',
#  'C',
#  'KOs2O6',
#  'Nb3Sn',
#  'FeSCs',
#  'LaOFeP',
#  'Rb',
#  'LaFePO',
#  'CePt3Si',
#  'Tl',
#  'PCCO',
#  'INS',
#  'FeSC',
#  'PbTaSe2',
#  'Sr2RuO4',
#  'PdTe2',
#  'RbOs2O6',
#  'Nb2PdS5',
#  'BiS2',
#  'Ce2PdIn8',
#  'Hg',
#  'BSCCO',
#  'CeRhIn5',
#  'CaKFe4As4',
#  'Bi2Sr2CaCu2O8',
#  'Sn',
#  'IBSCs',
#  'Si',
#  'Re',
#  'SrTiO3',
#  'SrPd2Ge2',
#  'Pr',
#  'Mn',
#  'BaNi2P2',
#  'YBaCuO',
#  'FeAs',
#  'Ce',
#  'PCS',
#  'Cs',
#  'Zn',
#  'ZrNCl',
#  'Yb',
#  'TiNCl',
#  'LiFeP',
#  'Li',
#  'MgCNi3',
#  'Se',
#  'IrGe',
#  'CNTs',
#  'NbTi',
#  'Lu2Fe3Si5',
#  'FeTe',
#  'BaNi2As2',
#  'CuRh2S4',
#  'Bi4O4S3',
#  'Cd',
#  'UIr',
#  'CuFeSb',
#  'Bi2Se3',
#  'Pd',
#  'Ru',
#  'La',
#  'Cr',
#  'FeSe',
#  'Be',
#  'Ca',
#  'Lu',
#  'Ta',
#  'Ga',
#  'UCoGe',
#  'Sm',
#  'SnTe',
#  'NCCO',
#  'Pt',
#  'Li2Pt3B',
#  'UGe2',
#  'LaPdSi3',
#  'UTe2',
#  'UPt3',
#  'URhSi',
#  'GaAs',
#  'RuSr2GdCu2O8',
#  'Gd',
#  'Ba',
#  'HTc',
#  'MgO',
#  'Sc',
#  'Sc3CoC4',
#  'BiO',
#  'Ge',
#  'Li2Pd3B',
#  'P',
#  'SH',
#  'Nd',
#  'NbSe2',
#  'Sb',
#  'Sr',
#  'SrO',
#  'HgTe',
#  'Zr',
#  'IP',
#  'Te',
#  'No',
#  'Bi',
#  'O',
#  'Na',
#  'He',
#  'Mg',
#  'Y',
#  'CuO2',
#  'CP',
#  'MoGe',
#  'MgB2',
#  'Ti',
#  'TiN',
#  'IV',
#  'SS',
#  'YBCO']

# %%
model = Word2Vec.load("training/tmp/arxiv_test_epoch29.model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dc32229f07f1> in <module>
# ----> 1 model = Word2Vec.load("training/tmp/arxiv_test_epoch29.model")
#
# NameError: name 'Word2Vec' is not defined

# %%
words = model.wv.most_similar(positive = ["high-tc", "high-tc_superconductors", "htsc"], topn = 5000)

# %%
words
# Out:
# [('cuprate', 0.981789231300354),
#  ('materials.', 0.9739264845848083),
#  ('experimental_evidence', 0.972754180431366),
#  ('discovery', 0.9706592559814453),
#  ('conductors', 0.9695954322814941),
#  ('have_shown', 0.9677539467811584),
#  ('magnetic_properties', 0.9642051458358765),
#  ('discovered', 0.9608942270278931),
#  ('manganites.', 0.9598421454429626),
#  ('high-tc_cuprates', 0.9586198329925537),
#  ('cuprate_superconductors', 0.9574148654937744),
#  ('physical_properties', 0.956777036190033),
#  ('layered', 0.9566489458084106),
#  ('recent_experiments', 0.9503173232078552),
#  ('unconventional', 0.9502008557319641),
#  ('cmr', 0.9483513832092285),
#  ('much_attention', 0.9471165537834167),
#  ('high-temperature', 0.9471077919006348),
#  ('electronic_properties', 0.9466816782951355),
#  ('alloys', 0.9464808702468872),
#  ('organic', 0.9458091259002686),
#  ('magnetism', 0.9450899362564087),
#  ('superconductors.', 0.9430073499679565),
#  ('superconductivity.', 0.9425532221794128),
#  ('phenomenology', 0.9425202012062073),
#  ('novel', 0.9422509670257568),
#  ('cuprates.', 0.9391118288040161),
#  ('type-ii', 0.9389438629150391),
#  ('heavy-fermion', 0.9385247230529785),
#  ('charge-lattice', 0.9380525946617126),
#  ('has_attracted', 0.9372355937957764),
#  ('crystals.', 0.9370839595794678),
#  ('pacs_numbers_typeset_using', 0.9354779720306396),
#  ('keywords', 0.9344311356544495),
#  ('widely', 0.9331895112991333),
#  ('transport_properties', 0.9330349564552307),
#  ('manganites', 0.9319790601730347),
#  ('metal-insulator_transition', 0.9316033720970154),
#  ('cugeo3', 0.9308720827102661),
#  ('josephson_effect', 0.9308534860610962),
#  ('more_recently', 0.9307507276535034),
#  ('reveal', 0.9293612241744995),
#  ('these_materials', 0.9293439388275146),
#  ('mechanism.', 0.9278057813644409),
#  ('demonstrated', 0.9263063669204712),
#  ('has_recently_been', 0.9262024760246277),
#  ('materials', 0.9259503483772278),
#  ('quasi-1d', 0.92549067735672),
#  ('have_attracted', 0.9253991842269897),
#  ('electrical_transport', 0.9248110055923462),
#  ('antiferromagnetism', 0.9245893955230713),
#  ('pacs_numbers', 0.9239491820335388),
#  ('quantum_tunneling', 0.9238082766532898),
#  ('low-dimensional', 0.923458456993103),
#  ('la1x_srx_mno3', 0.9231964945793152),
#  ('dmaals', 0.9228653907775879),
#  ('heavy_fermion', 0.9215588569641113),
#  ('theoretically', 0.92030930519104),
#  ('has_been_observed', 0.9200712442398071),
#  ('colossal_magnetoresistance', 0.9199504852294922),
#  ('metals', 0.9193078875541687),
#  ('was_recently', 0.9185793399810791),
#  ('cold', 0.917047381401062),
#  ('proximity_effect', 0.9165940284729004),
#  ('intense', 0.9155241250991821),
#  ('numerous', 0.9153616428375244),
#  ('rich', 0.9142208099365234),
#  ('electronic_transport', 0.9139162302017212),
#  ('recent_years', 0.9126009941101074),
#  ('la2_cuo4', 0.9125049114227295),
#  ('have_been_studied', 0.9122021794319153),
#  ('metals.', 0.9119179248809814),
#  ('order_to_understand', 0.9118950366973877),
#  ('quantum_tunnelling', 0.911514401435852),
#  ('revtex_i._introduction', 0.9109591841697693),
#  ('bechgaard', 0.910243809223175),
#  ('optical_properties', 0.9102230072021484),
#  ('spin_glasses', 0.9100952744483948),
#  ('high_pressure', 0.9098968505859375),
#  ('consensus', 0.9094647765159607),
#  ('has_been_proposed', 0.908691942691803),
#  ('manifestation', 0.9085733890533447),
#  ('nanostructures', 0.9085132479667664),
#  ('experimental_studies', 0.9077730178833008),
#  ('theoretical_work', 0.9074242115020752),
#  ('perovskite', 0.9065295457839966),
#  ('systematic_study', 0.9060628414154053),
#  ('interplay_between', 0.9050514698028564),
#  ('magnets', 0.9047322273254395),
#  ('high-tc_materials', 0.904484748840332),
#  ('great_interest', 0.9035714864730835),
#  ('conductor', 0.9033703804016113),
#  ('relevance', 0.9030433893203735),
#  ('peculiar', 0.902269721031189),
#  ('single-domain', 0.901835560798645),
#  ('light_scattering', 0.9015201330184937),
#  ('spin-peierls', 0.9014650583267212),
#  ('fascinating', 0.901155412197113),
#  ('low-tc', 0.901136577129364),
#  ('unfolding', 0.900476336479187),
#  ('controversy', 0.9003492593765259),
#  ('typeset_using_revtex', 0.899867057800293),
#  ('oxides', 0.899626612663269),
#  ('microstructures', 0.8995160460472107),
#  ('transition_metal', 0.8993874788284302),
#  ('focused', 0.8993477821350098),
#  ('sr2_ruo4', 0.8991008400917053),
#  ('f-wave', 0.8987714052200317),
#  ('ordering.', 0.8985215425491333),
#  ('date', 0.8984545469284058),
#  ('ments', 0.8984100818634033),
#  ('percolative', 0.8981207013130188),
#  ('chiral-glass', 0.8980584144592285),
#  ('underdoped_cuprate', 0.8977382183074951),
#  ('ceramic', 0.8973217010498047),
#  ('ceru2', 0.8973170518875122),
#  ('argued_that', 0.8966823816299438),
#  ('pacs', 0.8964282274246216),
#  ('technological', 0.8962824940681458),
#  ('showed_that', 0.8961732983589172),
#  ('have_revealed', 0.8955081105232239),
#  ('emergence', 0.8954320549964905),
#  ('ferromagnetic_metal', 0.8950774669647217),
#  ('magnetically_ordered', 0.8944129943847656),
#  ('recognized', 0.8943531513214111),
#  ('concentrated', 0.8938235640525818),
#  ('typeset_using_revtex_i.', 0.8937313556671143),
#  ('type-a', 0.8936024308204651),
#  ('doped_manganites', 0.8933342695236206),
#  ('irreversible', 0.8928703665733337),
#  ('development', 0.8928657174110413),
#  ('studied_extensively', 0.8926018476486206),
#  ('oxide', 0.8925979137420654),
#  ('proposal', 0.892418622970581),
#  ('tmtsf2pf6', 0.8917050361633301),
#  ('experimental_observations', 0.8913481831550598),
#  ('explaining', 0.8909832239151001),
#  ('conclusion_we_have', 0.890877366065979),
#  ('ferromagnets.', 0.8907005786895752),
#  ('cuprates', 0.8906490802764893),
#  ('superconductors', 0.8902999758720398),
#  ('hts', 0.8899412155151367),
#  ('ferromagnets', 0.8898289799690247),
#  ('spin-phonon', 0.8893479704856873),
#  ('regarding', 0.889274001121521),
#  ('elemental', 0.8885355591773987),
#  ('highly', 0.8884444832801819),
#  ('attention', 0.8881288766860962),
#  ('had_been', 0.8879687786102295),
#  ('unexpected', 0.8875138759613037),
#  ('industrial', 0.887454628944397),
#  ('largely', 0.8873021602630615),
#  ('challenging', 0.8872828483581543),
#  ('inorganic', 0.8868082165718079),
#  ('pseudo-gap', 0.8867045044898987),
#  ('cooperative', 0.8865565061569214),
#  ('demonstrated_that', 0.8864213228225708),
#  ('characterization', 0.8857372999191284),
#  ('variety', 0.885498046875),
#  ('scanning_tunneling', 0.8854061365127563),
#  ('partly', 0.8852347135543823),
#  ('i._introduction', 0.884311318397522),
#  ('manganite', 0.8842356204986572),
#  ('based_upon', 0.8840500116348267),
#  ('topics', 0.8839722871780396),
#  ('compounds', 0.8839202523231506),
#  ('mesoscopic_physics', 0.8829749226570129),
#  ('thin_films', 0.8820775747299194),
#  ('nd2x_cex_cuo4', 0.8820501565933228),
#  ('mesoscopic_systems', 0.8817293643951416),
#  ('present_work', 0.8815690279006958),
#  ('nanoparticles', 0.8812960386276245),
#  ('intriguing', 0.8809351921081543),
#  ('liquid_phase', 0.880834698677063),
#  ('great_deal', 0.8807939291000366),
#  ('great', 0.8806326389312744),
#  ('liquid_crystals', 0.8805667161941528),
#  ('mixed_state', 0.8804055452346802),
#  ('meissner', 0.8803826570510864),
#  ('ube13', 0.8800302743911743),
#  ('pacs_numbers_i._introduction', 0.8785575032234192),
#  ('fflo', 0.8785250186920166),
#  ('ago', 0.8780791163444519),
#  ('unusual', 0.8776835799217224),
#  ('this_letter', 0.8771029710769653),
#  ('la1x', 0.8768618106842041),
#  ('recent_experimental', 0.8765074610710144),
#  ('implications', 0.8764859437942505),
#  ('spin-dependent', 0.8764269351959229),
#  ('circuits', 0.8762300610542297),
#  ('cax_mno3', 0.8756845593452454),
#  ('have_been_performed', 0.8755491971969604),
#  ('granular_materials', 0.8753217458724976),
#  ('heavily', 0.8752716779708862),
#  ('stimulated', 0.8749610781669617),
#  ('magnetotransport', 0.874730110168457),
#  ('intensive', 0.8746678829193115),
#  ('low_temperature.', 0.87464439868927),
#  ('charge-density-wave', 0.8746311068534851),
#  ('few_years', 0.8742194175720215),
#  ('quasi-one-dimensional', 0.8742083311080933),
#  ('high-tc_superconductivity', 0.8742066621780396),
#  ('disordered_systems', 0.8741351962089539),
#  ('nickelates', 0.873994767665863),
#  ('currently', 0.8735361099243164),
#  ('very_interesting', 0.8734781742095947),
#  ('superconductivity', 0.8733038902282715),
#  ('superconducting_phase', 0.8733027577400208),
#  ('charge_ordering', 0.8731496334075928),
#  ('observations', 0.8731234073638916),
#  ('exhibiting', 0.8731228113174438),
#  ('gd2', 0.8727383613586426),
#  ('believed_that', 0.8726373314857483),
#  ('pointed_out', 0.8724907636642456),
#  ('been_observed', 0.8722864985466003),
#  ('promising', 0.8722754120826721),
#  ('theoretical_studies', 0.872272789478302),
#  ('topology', 0.8716162443161011),
#  ('have_been_made', 0.8713433742523193),
#  ('la1.88_sr0.12_cuo4', 0.8712244629859924),
#  ('similarities', 0.871137261390686),
#  ('spectroscopy', 0.8708617091178894),
#  ('material', 0.8702892065048218),
#  ('was_studied', 0.8702535629272461),
#  ('solid-state', 0.870233416557312),
#  ('observed_experimentally', 0.870191216468811),
#  ('instabilities', 0.8697673082351685),
#  ('ductors', 0.8693892955780029),
#  ('superconducting_state.', 0.8691303730010986),
#  ('semiconductors', 0.8689851760864258),
#  ('lot', 0.8688494563102722),
#  ('analysed', 0.8684548139572144),
#  ('hot', 0.8681848049163818),
#  ('molecular_clusters', 0.867892861366272),
#  ('high_temperature_superconductors', 0.8675739765167236),
#  ('encapsulated', 0.8670547604560852),
#  ('studies', 0.866904616355896),
#  ('deed', 0.8661320209503174),
#  ('developments', 0.8660101890563965),
#  ('epitaxial', 0.8655126094818115),
#  ('mqt', 0.8653193712234497),
#  ('efforts', 0.8651540279388428),
#  ('triggered', 0.8649165630340576),
#  ('years_ago', 0.8646625280380249),
#  ('fractons', 0.864619255065918),
#  ('revtex', 0.8644925355911255),
#  ('hall_effect', 0.8642328381538391),
#  ('stripe_phase', 0.8639534711837769),
#  ('behaviour.', 0.8638961315155029),
#  ('commonly', 0.8638173341751099),
#  ('compaction', 0.8634519577026367),
#  ('stabilized', 0.8631531596183777),
#  ('magneto-optical', 0.8631464242935181),
#  ('question.', 0.8630229234695435),
#  ('years', 0.8629687428474426),
#  ('transport.', 0.8628661036491394),
#  ('has_been_made', 0.8627333641052246),
#  ('ductors.', 0.862582266330719),
#  ('ni-substituted', 0.8620370626449585),
#  ('outofplane', 0.8620105981826782),
#  ('anomalies', 0.8617761135101318),
#  ('superconductor.', 0.8615923523902893),
#  ('pairing_mechanism', 0.8608705997467041),
#  ('devices', 0.8606584668159485),
#  ('suggested.', 0.8606112003326416),
#  ('compound', 0.8604397773742676),
#  ('research.', 0.860118567943573),
#  ('raises', 0.8599773645401001),
#  ('decoherence_rate', 0.8599756360054016),
#  ('glasses.', 0.8598934412002563),
#  ('pioneering', 0.8596750497817993),
#  ('evidence', 0.8595574498176575),
#  ('recent_theoretical', 0.8592637777328491),
#  ('highly_anisotropic', 0.8592408895492554),
#  ('controversial', 0.8592307567596436),
#  ('arpes_spectra', 0.8590769171714783),
#  ('viewpoint', 0.8578662872314453),
#  ('nix', 0.8577722311019897),
#  ('magnetisation', 0.8577005863189697),
#  ('alkali', 0.857050359249115),
#  ('microscopy', 0.857001543045044),
#  ('offer', 0.8568989038467407),
#  ('mott', 0.8568395376205444),
#  ('probing', 0.8568042516708374),
#  ('spite', 0.8565085530281067),
#  ('paradigm', 0.8563825488090515),
#  ('devices.', 0.856255054473877),
#  ('clarify', 0.8560997247695923),
#  ('mpb', 0.8557491302490234),
#  ('excited_levels', 0.8557279109954834),
#  ('cu4', 0.8555254936218262),
#  ('n-s', 0.8553812503814697),
#  ('implication', 0.8552380800247192),
#  ('high_temperature', 0.8550194501876831),
#  ('dmagas', 0.8549949526786804),
#  ('issues', 0.85498046875),
#  ('heavyfermion', 0.8548810482025146),
#  ('so_far.', 0.8547343015670776),
#  ('investigations', 0.8546314239501953),
#  ('believed', 0.8545305132865906),
#  ('believed_to_be', 0.854503870010376),
#  ('o8', 0.8543596267700195),
#  ('subtle', 0.8540726900100708),
#  ('compelling', 0.8540472388267517),
#  ('have_been_proposed', 0.8539156913757324),
#  ('phonon-electron', 0.8538686037063599),
#  ('pr1x', 0.8534515500068665),
#  ('disordered_metals', 0.8532575964927673),
#  ('last_decade', 0.8532003164291382),
#  ('tures', 0.8530352115631104),
#  ('recently_been', 0.8529675006866455),
#  ('spin-lattice', 0.8526825904846191),
#  ('debate.', 0.8526511192321777),
#  ('suggestive', 0.852641224861145),
#  ('charge_ordered', 0.8526033163070679),
#  ('explore', 0.8524805307388306),
#  ('these_observations', 0.8521421551704407),
#  ('salts', 0.8519532084465027),
#  ('electrical', 0.8518410921096802),
#  ('years.', 0.8517591953277588),
#  ('phenomena.', 0.8514881134033203),
#  ('rbmnf3', 0.8511849641799927),
#  ('recently', 0.8508918285369873),
#  ('spinglass', 0.85053551197052),
#  ('htls', 0.850227952003479),
#  ('perconducting', 0.8500901460647583),
#  ('suspensions', 0.8498445749282837),
#  ('electron-electron_interactions', 0.8498444557189941),
#  ('mqc', 0.8498172760009766),
#  ('compounds.', 0.849804162979126),
#  ('josephson_junctions', 0.8493249416351318),
#  ('properties.', 0.8492883443832397),
#  ('pioneering_work', 0.8492575883865356),
#  ('posed', 0.8491911888122559),
#  ('been_studied', 0.8489998579025269),
#  ('striking', 0.8489031791687012),
#  ('discussed._pacs', 0.8487268686294556),
#  ('this_article', 0.8484560251235962),
#  ('bio3', 0.8484076857566833),
#  ('did', 0.8483784198760986),
#  ('competing', 0.8482913970947266),
#  ('ije', 0.8481321334838867),
#  ('investigating', 0.8478672504425049),
#  ('experimentally.', 0.8477945327758789),
#  ('nuclear', 0.8475303649902344),
#  ('bring', 0.847447395324707),
#  ('insulators', 0.8474034070968628),
#  ('semiconductor', 0.8472328186035156),
#  ('resistance_oscillation', 0.8472008109092712),
#  ('important_role', 0.8471729755401611),
#  ('non-magnetic', 0.8471001386642456),
#  ('antiferromagnets', 0.8469079732894897),
#  ('we_have_studied', 0.8468574285507202),
#  ('longrange', 0.8466439247131348),
#  ('addressed', 0.8464809060096741),
#  ('conductors.', 0.8463371396064758),
#  ('electron-phonon', 0.8462549448013306),
#  ('magnetic_impurities', 0.8461377024650574),
#  ('phase_transition.', 0.8460369110107422),
#  ('freezing', 0.845562219619751),
#  ('polarons.', 0.8455530405044556),
#  ('nonlinear_optical', 0.8454973101615906),
#  ('striped', 0.8451682329177856),
#  ('sulfur', 0.8451116681098938),
#  ('researchers', 0.8449612855911255),
#  ('heisenberg_antiferromagnet', 0.8448530435562134),
#  ('spin-liquid', 0.8447787165641785),
#  ('fullerenes', 0.8447757959365845),
#  ('extensively', 0.8445785045623779),
#  ('type_ii', 0.8444863557815552),
#  ('pzt', 0.8444551229476929),
#  ('o4', 0.8444086313247681),
#  ('la2_cuo4y', 0.8441768884658813),
#  ('hindered', 0.8441343307495117),
#  ('quantum_dots', 0.8438742160797119),
#  ('semiconductors.', 0.8438624143600464),
#  ('quenched', 0.8436931371688843),
#  ('vibrations', 0.8435940742492676),
#  ('interplay', 0.8433876633644104),
#  ('observations.', 0.8433470726013184),
#  ('fects', 0.8431752324104309),
#  ('spectroscopic', 0.8429920077323914),
#  ('advances', 0.842963457107544),
#  ('wide_range', 0.8429064750671387),
#  ('mesoscopic', 0.8428171873092651),
#  ('structural', 0.8426583409309387),
#  ('fe3', 0.8425577878952026),
#  ('put_forward', 0.8424513339996338),
#  ('distinctive', 0.8423433899879456),
#  ('intermetallic', 0.8423295617103577),
#  ('suppressed.', 0.8422867655754089),
#  ('debated', 0.842146635055542),
#  ('opens_up', 0.8421448469161987),
#  ('biaxial', 0.8419327735900879),
#  ('nanometer-scale', 0.8418493270874023),
#  ('challenge', 0.8416463136672974),
#  ('neutron_resonance', 0.8414576649665833),
#  ('high-quality', 0.8414435386657715),
#  ('there_are_several', 0.8413651585578918),
#  ('material.', 0.8411767482757568),
#  ('switches', 0.84111487865448),
#  ('transitions.', 0.8410776853561401),
#  ('enormous', 0.8408633470535278),
#  ('summary_we_have', 0.8408191204071045),
#  ('tilting', 0.8407816290855408),
#  ('thermopower', 0.8406687378883362),
#  ('nanoscale', 0.8406678438186646),
#  ('nanofabrication', 0.8403874635696411),
#  ('time-resolved', 0.8403805494308472),
#  ('quantum_chaos', 0.8401795029640198),
#  ('aware', 0.8401567935943604),
#  ('direct_evidence', 0.8401141166687012),
#  ('limitation.', 0.8400936722755432),
#  ('has_been_extensively', 0.8399878740310669),
#  ('intensively', 0.8399696350097656),
#  ('revealed', 0.8396708965301514),
#  ('we_report', 0.8395055532455444),
#  ('liquids', 0.8394728899002075),
#  ('puzzling', 0.8392385840415955),
#  ('transport_through', 0.8390004634857178),
#  ('catalytic', 0.8389907479286194),
#  ('appear_to_be', 0.8389784097671509),
#  ('flcs', 0.838961124420166),
#  ('netic', 0.8387997150421143),
#  ('ferroand', 0.8385263681411743),
#  ('physicists', 0.838495135307312),
#  ('he4', 0.8384236097335815),
#  ('qwrs', 0.8381461501121521),
#  ('inelastic_neutron_scattering', 0.8381164073944092),
#  ('low-temperature', 0.8379379510879517),
#  ('x-ray_scattering', 0.8378008604049683),
#  ('d-wave_superconductors', 0.8377699851989746),
#  ('semiconductor_quantum', 0.8377152681350708),
#  ('also_been', 0.8376888036727905),
#  ('rare', 0.8375020027160645),
#  ('phenomenon.', 0.8373371958732605),
#  ('bapbx_bi1x_o3', 0.8367410898208618),
#  ('exotic', 0.8366448283195496),
#  ('bilayer', 0.8366075158119202),
#  ('ever', 0.836606502532959),
#  ('preparation', 0.8364803791046143),
#  ('high-resolution', 0.836300253868103),
#  ('processing', 0.8361056447029114),
#  ('melt', 0.8353108167648315),
#  ('inuence', 0.8353063464164734),
#  ('unifying', 0.8352950811386108),
#  ('content', 0.8351801633834839),
#  ('silo', 0.8348591327667236),
#  ('dichroism', 0.8345617055892944),
#  ('textured', 0.834542989730835),
#  ('low_temperatures.', 0.8345365524291992),
#  ('theoretical_description', 0.8344674110412598),
#  ('orbital_ordering', 0.8342322111129761),
#  ('upt3', 0.8342078328132629),
#  ('conducting', 0.8339730501174927),
#  ('colossal', 0.8339218497276306),
#  ('attracted', 0.8338707685470581),
#  ('giant', 0.8338050842285156),
#  ('features.', 0.8337991833686829),
#  ('emerged', 0.8337697982788086),
#  ('phase_transitions', 0.8336455225944519),
#  ('received', 0.8334066867828369),
#  ('ferrimagnets', 0.8333603739738464),
#  ('radaelli', 0.8332988023757935),
#  ('resolve', 0.8331714868545532),
#  ('offers', 0.8331558704376221),
#  ('low-intensity', 0.8331544399261475),
#  ('well_established', 0.833060085773468),
#  ('formers', 0.8328858613967896),
#  ('nonmagnetic', 0.8328796625137329),
#  ('strongly_correlated_electron', 0.8328186273574829),
#  ('srx_cuo4', 0.8327645063400269),
#  ('neutron_diffraction', 0.8326267004013062),
#  ('lasr2mn2o7', 0.8325411081314087),
#  ('has_been_discussed', 0.8324808478355408),
#  ('d-wave_superconductor', 0.832403302192688),
#  ('hybrid', 0.8322285413742065),
#  ('decade', 0.8320797681808472),
#  ('peculiarities', 0.8314169645309448),
#  ('texture', 0.8312612771987915),
#  ('doublers', 0.8311572074890137),
#  ('compound.', 0.8311413526535034),
#  ('bi2_sr2', 0.8310166597366333),
#  ('sal', 0.8307785987854004),
#  ('stage-4', 0.8306353688240051),
#  ('magnetometry', 0.8305562138557434),
#  ('bkbo', 0.8305070400238037),
#  ('issue', 0.8303170204162598),
#  ('technologies', 0.8300653100013733),
#  ('superlattices', 0.8300212621688843),
#  ('ascribed', 0.8299641013145447),
#  ('magnet', 0.8299623131752014),
#  ('evidenced', 0.8299155235290527),
#  ('high_magnetic_field', 0.8295385837554932),
#  ('rvb', 0.8293272852897644),
#  ('glassy', 0.8293225169181824),
#  ('substances', 0.8290198445320129),
#  ('l-p', 0.8284911513328552),
#  ('emphasized', 0.8284446001052856),
#  ('liquid_crystal', 0.8283431529998779)]

# %%
candidates = []
atom_lists = []
for word in list(zip(*words))[0]:
    if is_formula(word):
        atoms = atom_list(word)
        if atoms not in atom_lists:
            candidates.append(word)
            atom_lists.append(atoms)

# %%
candidates
# Out:
# []
