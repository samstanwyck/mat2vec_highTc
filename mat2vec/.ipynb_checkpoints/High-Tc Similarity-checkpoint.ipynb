# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from gensim.models import Word2Vec, KeyedVectors
from sklearn.manifold import TSNE
from scipy.spatial import distance

# %%
model = Word2Vec.load("training/models/pretrained_embeddings")

# %%
ELEMENTS = ["H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "Ar", "K",
            "Ca", "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Kr",
            "Rb", "Sr", "Y", "Zr", "Nb", "Mo", "Tc", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I",
            "Xe", "Cs", "Ba", "La", "Ce", "Pr", "Nd", "Pm", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb",
            "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au", "Hg", "Tl", "Pb", "Bi", "Po", "At", "Rn", "Fr",
            "Ra", "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", "Cm", "Bk", "Cf", "Es", "Fm", "Md", "No", "Lr", "Rf",
            "Db", "Sg", "Bh", "Hs", "Mt", "Ds", "Rg", "Cn", "Nh", "Fl", "Mc", "Lv", "Ts", "Og"]

# %%
def is_formula(formula):
        N = len(formula)
        i = 0
        while i < N:
            if formula[i].isupper():
                if i < N - 1 and formula[i+1].islower and str(formula[i]+formula[i+1]) in ELEMENTS:
                    if i < N-2 and formula[i+2].isdigit():
                        if i < N-3 and formula[i+3].isdigit():
                            i += 4
                        else:
                            i += 3
                    else:
                        i += 2
                elif formula[i] in ELEMENTS:
                    if i < N - 1 and formula[i+1].isdigit():
                        if i < N-2 and formula[i+2].isdigit():
                            i += 3
                        else:
                            i += 2
                    else:
                        
                        i += 1
                else:
                    return False
            else:
                return False  
            
        return True
    
    
def atom_list(formula):
        N = len(formula)
        atoms = []
        i = 0
        for i in range(N):
            if formula[i].isupper():
                if i < N - 1 and formula[i+1].islower and str(formula[i]+formula[i+1]) in ELEMENTS:
                    atoms.append(str(formula[i]+formula[i+1]))
                elif formula[i] in ELEMENTS:
                    atoms.append(formula[i])
                
        return atoms

# %%
w2c = dict()
for item in model.wv.vocab:
    if is_formula(item):
        w2c[item]=model.wv.vocab[item].count
w2cSorted=dict(sorted(w2c.items(), key=lambda x: x[1],reverse=True))
w2cSortedList = list(w2cSorted.keys())

# %%
embeddings = []
words = []
high_tc_similarity = []
for word in w2cSortedList[1:5000]:
    words.append(word)
    embeddings.append(model.wv[word])
    high_tc_similarity.append(model.wv.similarity(word, 'high-Tc_superconductor'))

# %%
viridis = cm.get_cmap('viridis', 12)
greys = cm.get_cmap('Greys', 12)

# %%
embeddings = np.array(embeddings)
tsne_model_in_2d = TSNE(perplexity=20, n_components=2, init = 'pca', n_iter=3500, random_state = 3)
embeddings_in_2d = np.array(tsne_model_in_2d.fit_transform(embeddings))

# %%
candidates = model.wv.most_similar(positive = ["high-Tc_superconductor", "high-T_c_superconductor",
                                             "high-Tc_superconductors", "high-T_c_superconductors"], 
                                  topn = 10000)

# %%
filtered_candidates = []
atom_lists = []
for word, _ in candidates:
    if is_formula(word):
        atoms = atom_list(word)
        if atoms not in atom_lists:
            filtered_candidates.append(word)
            atom_lists.append(atoms)

# %%
filtered_candidates
# Out:
# ['Bi2CaCu2O8Sr2',
#  'Ba2Cu3O7Y',
#  'BSCCO',
#  'Ba2CaCu2O8Tl2',
#  'YBCO',
#  'Cu20La37O80Sr3',
#  'Ce3Cu20Nd37O80',
#  'BaBiOPb',
#  'Bi2CaCu2Sr2',
#  'BaCaCuHgO',
#  'Ba2Cu4Ho',
#  'BaCuLaOSr',
#  'As20Fe20O17Sm20',
#  'Cu2O7',
#  'Ag3Ba20Cu27Y10',
#  'Bi2LaPb2Sr',
#  'Ba8Cu12LuO28Y3',
#  'Ba2BiCa10Cu15O5PbSr8Tl4',
#  'BaCaCuOY',
#  'Ba3Cu20La37O80',
#  'Ce3Cu20La20O80Pr17',
#  'Cr3Cu10Hg7O40Sr20',
#  'Ba2CuO6Tl2',
#  'As3Cr3K2',
#  'As10FFe10Nd10O9',
#  'BaBiPbSr',
#  'B2CNi2Y',
#  'Ba2CaTl2',
#  'BBi2C2CaCu2O9SSr2',
#  'Ba20Cu30Eu10O69',
#  'HBCCO',
#  'Ba2CuHgO4',
#  'Ce3Cu20Eu37O80',
#  'Ba3Cu6Gd3O14',
#  'Tc',
#  'As3Cr3Rb2',
#  'Bi2CaCu2IO8Sr2',
#  'As50Ba25Co2Fe48',
#  'Ca8Cu20O70Pb5Sr20Tl5Y2',
#  'B2RuY',
#  'Ba2Cu3O7Yb',
#  'Ge3NiY',
#  'Ba3Bi5K2O15',
#  'Ba2Cu30Y',
#  'AsFFeGdO',
#  'Ba2Cu2O7TlY',
#  'As25F2Fe25La25O23',
#  'CeCoIn',
#  'Bi2CaO8Sr2',
#  'LaMo6Se8',
#  'CuLaNdOSr',
#  'BaCaCuFHgO',
#  'Ba2Ca2Cu3Tl2',
#  'NCCO',
#  'Ba2Cu3O7',
#  'As40Ba13Fe40K7',
#  'BISCCO',
#  'B5C5O33Y5',
#  'BaTl',
#  'O4RuSr2',
#  'Ba2Cu3O7Pr',
#  'La37Sr3',
#  'BaY',
#  'As10Fe10Nd10O7',
#  'Bi21Cu10O60Sr19',
#  'Ba2Ca10Cu15O5Pb5Sr8Tl5',
#  'Ca5Cu10O34Sr10Tl5',
#  'Ce3Cu20O80Sm37',
#  'CuLa2O4',
#  'Ba2Cu4HoO8',
#  'Pb2Sr',
#  'Ce3Cu20O80Pr37',
#  'Ba2Nd',
#  'As2CsFe2',
#  'Ba2CaCu2O8Sr2',
#  'Bi2FOS4',
#  'Ba4O12Pb3Sb',
#  'AsFFeSm',
#  'B2CPt2Y',
#  'Cu20La11O61Pb20Sr9',
#  'Ca4Cu6O18PbSr4Tl',
#  'Ba2Cu4ErO8',
#  'BaPb',
#  'Ca2Cu8O27Sm2Sr8Tl4',
#  'Bi2FNd2OS4',
#  'Bi9Ca10Pb2Sr10',
#  'CaRhSn',
#  'Ba25Cu40O90Sm6Yb9',
#  'As10La10Ni10O7',
#  'Ba2Cu3O7Sm',
#  'Cr3Tl17',
#  'Bi2Cu2O8Sr2Y',
#  'Bi2CaSr2',
#  'C20La37O80Sr3U20',
#  'In3Pb7',
#  'BeU',
#  'Cu10O31Sr20',
#  'Cu12O35Pb3Pr5Sr10',
#  'As13Ba10Fe20P7',
#  'As2Fe2Li',
#  'BaHg',
#  'Rh6Sn18Tm5',
#  'BiCaCuOPbSr',
#  'Ba2Cu2O7PrTl',
#  'CeCu4Gd3O20Ru2Sr4',
#  'As50Ba25Fe47Ni3',
#  'Ba3Sr2Tl5',
#  'As10F2Fe10O7Sm10',
#  'CaCuO8',
#  'Bi4O4S3',
#  'Ge2La3Rh2',
#  'BaGaGe',
#  'Ba2K3',
#  'BC2O8S',
#  'B3CLi2',
#  'BiCaCuPbSr',
#  'As5Fe5O5Pr4Sr',
#  'Ba2Pr',
#  'Ge2Ir2La3',
#  'Ba2Cu3O7Tm',
#  'AsCoLi',
#  'Bi2CaF2LaSe4',
#  'Bi2Cu2O8PrSr2',
#  'B3GeN',
#  'BFeS',
#  'BiCaCuOPbSnSr',
#  'Ba2Cu3DyO7',
#  'BRe13W7',
#  'FeSeTe',
#  'Cu10F3Nd20O37',
#  'CLaOS',
#  'B10Co69Y10',
#  'CdCe2Co2In9',
#  'As10Fe10O7Pr10',
#  'Cu17La40Ni3O80',
#  'Ba20Ca7Tl10Y3',
#  'CaCuOSr',
#  'RuSb5Zr10',
#  'Ba2CaHg',
#  'CaIrSi3',
#  'Ba15Ca5Cu30La7O10Y3',
#  'Ba10Co5Cu10La5O37',
#  'Bi2CCu2O11Sr4',
#  'EuRuSr2',
#  'LaRu3Si2',
#  'BPSCCO',
#  'Ge12LaPt4',
#  'Os4PrSb12',
#  'BiS2',
#  'Cu10GdO20Sr9',
#  'Cu2EuO8RuSr2',
#  'Ba2CO7U3Y',
#  'BaCaCu',
#  'La3Ru4Sn13',
#  'LaNiO4',
#  'PrSr2',
#  'CuO6Sn',
#  'BiC2OS',
#  'Nd2Sr5',
#  'BaGaSi',
#  'C2CuNO5',
#  'BISCO',
#  'AsFeNTh',
#  'Ba2CaCu3O6',
#  'BCSCO',
#  'CeCu5Nd7O20Sr2',
#  'Ba20Cu30O70PrY9',
#  'CuNd2O4',
#  'Ba2Cu3Nd',
#  'As4Fe4Gd2O2Rb',
#  'Ba2CeCu3O9Y',
#  'Cu3NdO12Ru4',
#  'Fe17K8Se20',
#  'B2CLuNi2',
#  'Ba2F2O2Pd',
#  'B12Ni19Y10',
#  'As9Eu5P6',
#  'As5BaF2Fe5Nd4O3',
#  'B2N3Ni2Th3',
#  'YBKCO',
#  'Pb3Tl',
#  'KO6Os2',
#  'Ba4Cu6GdO2Sm',
#  'BKBO',
#  'Ba2Cu',
#  'Ba4Cu6O14SmY',
#  'Ba2Cu3F2OY',
#  'Mo6S8Yb',
#  'C20Ce3Nd37O80U20',
#  'Cu3OY',
#  'B2Cu3O7Y',
#  'Ge3Nb7',
#  'KOs',
#  'BiCu2HgO15SbSr7',
#  'Cu5La6O20Pr3Sr',
#  'Ca3Ir4Sn13',
#  'Cu2O8RuSr2Y',
#  'As40Co3Fe37La40O40',
#  'BaCu3O7SrY',
#  'CeHg',
#  'PbSe2Ta',
#  'HgRe',
#  'Ba2Cu3DyO7Y',
#  'B2CLaPt2',
#  'BiCuSr',
#  'Ca10Cu20Nd7O70Sr13Tl10',
#  'AlBi19Ca20Cu40O20Sr20',
#  'Ba20Ca20Cu30Hg7O80Pb3',
#  'Cu20Gd10LaO80Ru10Sr19',
#  'FISC',
#  'Ca8Pb5Sr20Tl5Y2',
#  'ClCuH3O3Sr',
#  'GdRu',
#  'Cl7N10Zr10',
#  'Ir4Sc5Si10',
#  'B2LuNi2',
#  'B4NdRh4',
#  'Cu3O8Pb2Sr2Y',
#  'Ba19Cu30PrSrY9',
#  'Bi2CaCu4O16Pb2Sr4Y',
#  'B16Ir19Mg10',
#  'CsFeS',
#  'BSCC',
#  'As50Ca25Fe49Ni',
#  'Ba10Bi6Cu8La4O33',
#  'B2Mg',
#  'La3Tl',
#  'Co3Zn40',
#  'Ba2Cu3U7Y',
#  'Ge12PrPt4',
#  'Ba2Eu',
#  'B4Rh4Sm',
#  'Ba20Ca20Cu30Hg8O81Tl2',
#  'LaRu8Si8U3',
#  'BaC15',
#  'Al3Pd2U',
#  'CoGaPu',
#  'Nb2PdS5',
#  'BBaCuNdO5',
#  'Ba10Cu14O5Zn',
#  'BSCYCO',
#  'B2CLaNi2',
#  'Ba2CaO8Tl2',
#  'Cu4Gd3GeO20Ru2Sr4',
#  'Bi10Ce10F7O3S20',
#  'Ce3Cu10O50Ru5Sm7Sr10',
#  'FeLa14Mn19O60Sr6',
#  'As2Ni2Sr',
#  'Ga4HfV2',
#  'CsO6Os2',
#  'Bi2LaO2S4Th',
#  'Cl25Li3N25Zr25',
#  'AlCe5Fe9',
#  'As4Ba2Cr2OTi2',
#  'CaCu2La2O7',
#  'DyMo6S8',
#  'BiCaCuOSrY',
#  'B20Dy2Rh20Y3',
#  'BaHo',
#  'Ba2Cu3IO6Y',
#  'C79Th15Y35',
#  'Bi2Sr2Y',
#  'BiF2S2',
#  'In5PuRh',
#  'In4Sb',
#  'As2Fe2K',
#  'As20CoFe19Na20',
#  'CeInIr',
#  'As25Fe25Gd25O22',
#  'HSTc',
#  'Ba2DyNbO6',
#  'Nb5Re24',
#  'CeIn5',
#  'As10FLa10Ni10O9',
#  'As10Fe10Na9',
#  'Ca9Ce',
#  'Bi8NbSe12',
#  'Cu9Mo30S40',
#  'CoYb',
#  'Al16Ge4Nb65',
#  'Ba20Cu27Fe3O69Y10',
#  'Ba10Ca10Cu15Hg5O5Re',
#  'CuSe20Ti10',
#  'Bi3Mn4O12Sr',
#  'CaPtSi3',
#  'As5CaFePt2',
#  'FeOTe',
#  'HoMo6S8',
#  'LaPdSi3',
#  'Ba2Cu3NdO7',
#  'Ba2C3O7Y',
#  'Fe20Se17',
#  'B10C5Er4Ni10Tb',
#  'GdTe3',
#  'Ba2C7Cu3Y',
#  'O4S3',
#  'Ba3CaCu6La2O2',
#  'As4CaFe4K',
#  'BCDyOY',
#  'CsFO29W10',
#  'F3Tl',
#  'C20Ca17O40Sr3U20',
#  'Ce5Eu7Ru5Sr10',
#  'AlLaO6SrTi',
#  'Ce5Gd',
#  'PCCO',
#  'As5FFe5O4Pr5',
#  'CaCu',
#  'Ba19Pr2Y9',
#  'BaNiO5',
#  'BC2OTl',
#  'Ge2Pd2Sr',
#  'TeTl9',
#  'CaCuO4PbSr',
#  'NdYb9',
#  'B10C5Er4LuNi10',
#  'Pd2Th',
#  'LaPd2Sb2',
#  'Eu23Yb2',
#  'AsFeORe',
#  'NiS50Ta25',
#  'Ce5Cu11Si10',
#  'Bi2Ca2Cu3F4O8Sr2',
#  'BRh4Si2Y',
#  'Ba2Tm',
#  'B3Nb25Si12',
#  'Mn2O7',
#  'Ba2Sb6Sn3',
#  'C3Ge30Nb50',
#  'NiO3PScSr2',
#  'SSmY',
#  'HfNbTi',
#  'As2EuFe',
#  'B4Rh4Y',
#  'CoLa2',
#  'Cu2GdO8RuSr2',
#  'Cl2Cu3O4Sr2',
#  'La3Ni4O2P4',
#  'CeCu4Eu3O20Ru2Sr4',
#  'Nb16Ta3Ti18Zr3',
#  'CuGd2O4',
#  'Cu3Rh3S8',
#  'BaCaCuLa',
#  'BLuRh4Si2',
#  'BaTaY',
#  'CeGe3Ni',
#  'Ce3Cu10Gd7',
#  'Bi2Fe3O12Sr4',
#  'CuNdO2Sr',
#  'Cs2Fe5Se5',
#  'B2CErNi2',
#  'CuSr2',
#  'B8C4Ho3Ni8Y',
#  'CeFeOP',
#  'EuFe',
#  'Cu5La4O20Sm5Sr',
#  'Ca2CuPb3Sr8Y2',
#  'As7Eu5Fe10P3',
#  'Ca2Cl2CuO2',
#  'FO9',
#  'As2CuPr',
#  'FeLuMgO',
#  'HeTc',
#  'BCCaLaOPr',
#  'GaGeSr',
#  'Ba9La6Mn10O35',
#  'As20Ce20CoF2Fe19O18',
#  'La4Th',
#  'B15C2Pd25Y5',
#  'Mo6S4Se4Sn',
#  'Ce5La4Th',
#  'BaLa2NbO6',
#  'Ga5PuRh',
#  'B10C10CaO10Y10',
#  'B4Li8Pd9Pt3',
#  'As10FFe10O9',
#  'Nd2O4Pd',
#  'CuNaO2',
#  'As2Fe2OSr4V2',
#  'Ca8Cu20Pb5Pr2Sr20Tl5',
#  'Cu4EuGdO16Ru2Sr4',
#  'FeLaOP',
#  'Pt3U',
#  'Bi4Ce3Pt4',
#  'AsNiO3ScSr2',
#  'Ir4Lu5Si10',
#  'B4ErRh4',
#  'Ba2CmCu3O7',
#  'Ba10BiCa4Cu10Hg4O30Y',
#  'As4Fe5Na5P',
#  'OsPr',
#  'Pb3S',
#  'B2CNi2',
#  'Bi10Sr7',
#  'HfRe6',
#  'As2CaFe',
#  'La5Mn8O28Sr7',
#  'Cu2IrO8Sr2Tb',
#  'BPBO',
#  'Ba10Cu15O35Pr3Tm2',
#  'C2Ni',
#  'Ge3RhSr',
#  'AsFeLaO',
#  'B2LuRu',
#  'B15C2Pd25',
#  'Bi2FLa2OSe4',
#  'InNi4',
#  'Ba2Ca3Cu4Hg',
#  'Bi10Ca10Mn21O90Pb10Sr18',
#  'Ba20Bi3O60Pb14Sb3',
#  'C61H5K3N',
#  'HBCO',
#  'CaCo2La3O8',
#  'As2Fe2O5Sc2Sr3',
#  'Rh4Sn13Sr3',
#  'BiNdOS2',
#  'Ca5Pr',
#  'B12NZr',
#  'MnOTm',
#  'O6Os2Rb',
#  'Ca8Cu20Er2O10Pb5Sr20Tl5',
#  'As3Cr3Cs2',
#  'Bi50Cu25Nd12O25Sr38',
#  'AgLaSb2',
#  'Mo19Re',
#  'BInNi3',
#  'B6Ba15C4Ca20Cu30O90Sr5',
#  'Al2NpPd5',
#  'Mo11P5Ru9',
#  'BFe14HLa2',
#  'Al10Ce10Cu20O90Sr17Y33',
#  'AlCu2La6Ni',
#  'Be13Th',
#  'CuLaO5SrTl',
#  'CoO7Y9',
#  'CuF3Rb',
#  'Co3Y4',
#  'Bi2FOPr2S4',
#  'LaRhSi3',
#  'Ca3La6Mn10O30Pr',
#  'As2BaFe2',
#  'Os4Sb12Sm',
#  'Fe2LuSi2',
#  'F3Fe50La50O47P50',
#  'Ba3Bi4O12',
#  'BErRh4Si2',
#  'Co9La7MnO30Sr3',
#  'Ba2Cl2Cu3O4',
#  'CuHO2Tl',
#  'Ba10CaCu15Y4',
#  'BaLu2NiO5',
#  'Ca14Cu24La14O41Sr14',
#  'Mo15S20Tb3',
#  'GdSc',
#  'Pd2SbU',
#  'Co2O5',
#  'AsFe',
#  'As2LaPd2',
#  'Ba2Cu3Sm',
#  'Ba4CuFeGd2O',
#  'CoO5Sr2Ti',
#  'GaNi4Tb',
#  'EuSr5',
#  'LaOs2',
#  'AlAuU',
#  'FeO3PScSr2',
#  'C2NNdOS',
#  'Co2GeMn2',
#  'Bi39CoO40S30',
#  'Ba9Cu15LaO5Y5',
#  'OsRb',
#  'AsFeSe',
#  'C6H10NO',
#  'As40Eu17Fe20La3',
#  'Co5Gd4O20Sr6',
#  'BiCa2Cu4O14Sr4Tl',
#  'FeGa5Pu',
#  'Ag2C4CuH24N12',
#  'YBNCO',
#  'Fe2O8Sr3Tl',
#  'CoFeO6Ti2',
#  'Ba4CuTl',
#  'B38C2Mg20SiTi3',
#  'B2CHoNi2',
#  'Cu7Ir20S40Zn3',
#  'Ce5Co2In25Rh3',
#  'BBa2CCu3O12Y2',
#  'AlB20Mg9',
#  'Ba2NbO6Yb',
#  'CaCu2O2Tl2',
#  'Fe13Se20Tl10',
#  'Ga9Rh3Yb2',
#  'FeGdOP',
#  'Be13Lu',
#  'Na2Rb',
#  'Ba4Cu6O2Sn4SrY',
#  'As25Ca25Co3F25Fe22',
#  'Nd7Y3',
#  'PPt3Sr',
#  'As4CsEuFe4',
#  'BC2OPbS',
#  'Bi3CaMn4O12',
#  'CeMn20O60Sr19',
#  'CuO6Ru',
#  'Gd11Mn20O60Sr9',
#  'P2Pd2Pr',
#  'Ru2Si2Th',
#  'BaCu3La',
#  'AlNi2Yb2',
#  'BaNi2O8P2',
#  'MgPtSi',
#  'Cr3NRh',
#  'B80Dy12Rh77Ru3Y8',
#  'Er2Fe3Si5',
#  'As10Fe10K2Sr3',
#  'Ca10La7Mn10O30Sr3',
#  'B20Er2Ho3Rh20',
#  'BCS',
#  'YPBCO',
#  'Fe50S7Se43',
#  'BCO3',
#  'CoO6Ru',
#  'AsFeO3V',
#  'Bi10Cu5La2O5Sr8',
#  'B2Bi2CY',
#  'Ba10Ca5Hg4V',
#  'FeMoO6',
#  'Mo6S8Sn',
#  'As10Ce10FFe10O9',
#  'C2PtU2',
#  'CCu3Mg',
#  'Cu2Er2O5',
#  'CoTm12',
#  'Co25Na11O50',
#  'Pt3Ta17',
#  'CaGaSr2',
#  'SSeTa',
#  'LaOs4P12',
#  'Cu17Pb3',
#  'As2Fe2Rb',
#  'CuEu2O4',
#  'Bi5Ca4Mn10O30Sr',
#  'In5Rh',
#  'Lu5Rh4Si10',
#  'LaOs4Sb12',
#  'CCo3Mg',
#  'PtSiTa',
#  'Fe71S3Se64Te4',
#  'GaSe8Ta4',
#  'La7Y3',
#  'BCDyO',
#  'AsNNiTh',
#  'B9BeC10Li10',
#  'LaRh20Si20Yb9',
#  'Fe2Ge2Lu',
#  'BaCCaHgOPbU',
#  'CuGdIn',
#  'BiCa2InLa14Mn19O60Sr3',
#  'Ca5Mn20O60Pr13Sr2',
#  'IMo3S3',
#  'B10Ba3Bi5K7O20',
#  'BaC20K',
#  'Co4La3Sn13',
#  'FeTe8Ti4',
#  'Au6B20C10Nd10Pt15',
#  'FeHLiOSe',
#  'Ba2CaCu2O8Ti2',
#  'Cr14Ni',
#  'P2Pd2Y',
#  'CeTe3',
#  'Ca3La22Mn25O75',
#  'H4Nb',
#  'Ce5Cu21Hg4Nd10O10Sr20',
#  'LuMn',
#  'BCu5O2Sr4Y2',
#  'Cd2O7Re2',
#  'As2CaPd2Sr',
#  'CaCu3O12Ru4',
#  'Rh3Si5',
#  'BaC6Cu2O10Sr3',
#  'Ba5Bi3La2',
#  'CaCdCu4O14PbSr4Y',
#  'Ba9Cu15NdO5Y5',
#  'Cu5Dy4La5O20Sr',
#  'Al2CePd5',
#  'Ce5Cu3Ni2',
#  'BaCuErLaO',
#  'As10Fe10HO9Sm10',
#  'C60CsK2',
#  'Bi2Cu2O5',
#  'Er3Mo15S20',
#  'P2Rh2Sr',
#  'Ba2LuO6Re',
#  'RuSr2',
#  'B10C5Co3Ni7Y5',
#  'BiSe2',
#  'Ca17Eu3Mn20O60',
#  'Ca2CuSSr4',
#  'BNi3Sc',
#  'RuZr3',
#  'Ba20C5Ca2Cu25O70Y8',
#  'CIY',
#  'Ba18Bi5K2O60Pb15',
#  'Cl42CuH10N2O',
#  'Ga5NiPu',
#  'Er2Mn2O7',
#  'Cd22Fe3S25',
#  'Bi2FLa2OS4',
#  'BaFe2LaO6',
#  'Ce10RhRu19Si20',
#  'CoFe9Se10',
#  'Fe4P12Y',
#  'Cu2O10PbSr4Tl',
#  'Cl3RbTl',
#  'BeLi3',
#  'B2CDyNi2',
#  'LaPb2',
#  'InLa3',
#  'Cu2FeO8Sr2Y',
#  'B2CNdPt2',
#  'Bi2K',
#  'Ca3Ni10O40Pr17',
#  'Bi2Co2O9Sr2',
#  'LaRh2Si2Tc',
#  'GaGdNi4',
#  'Ba4O10Pb3',
#  'C3Cu2N3',
#  'Ge3Ni',
#  'B2O11Sb2Sr4',
#  'Ca3O7Ru2',
#  'CeP2Pd2',
#  'B12LuN',
#  'Cu10Hg3O50Pb7Sr20',
#  'Ce4Mn10O30PrSr5',
#  'Ba4BiCuOSm2',
#  'Mn24MoO75',
#  'Ca5Cu10Hg4O30V',
#  'GdMo6Se8',
#  'Bi22O51Sr18',
#  'Cr5RbS8',
#  'B2GeTa5',
#  'BaMn4Nd3O12',
#  'Sr2Y',
#  'CeIrSi',
#  'C4H16HgN8S4',
#  'Ca17Dy3Mn20O60',
#  'LuMo6S8',
#  'Ba3Ca3Mn20O60Pr14',
#  'CsDyO8W2',
#  'O4Rh2Sr',
#  'BiPb3S',
#  'Cd5Cr9InS20',
#  'Ba4Hf2Ho2O11',
#  'CoLa9Mn9O30',
#  'Ce3Ge2Rh2',
#  'O3ScSr2',
#  'CoFe19Ge40',
#  'Cm2CuO4',
#  'I2N3S',
#  'CeCu4Nb2O20Pr3Sr4',
#  'K9Na5',
#  'LaOs2P12Ru2',
#  'Br4C2CuH12N2',
#  'Ba20Ca10Cu20Hg8O43V2',
#  'Ni7Pd43',
#  'Cu6S4Tl',
#  'B4Ru4Sc',
#  'Cu2O7Sr2TlY',
#  'B2CNi2Th',
#  'Ce3Ru4Sn13',
#  'B2O11Sb2',
#  'IrU',
#  'CeCu3Eu3OPb2Sr2',
#  'BiCo5Tm12',
#  'Br2CaSr2',
#  'B8MgNb3',
#  'LaRu4Sb12',
#  'BaNiY2',
#  'Ba2BiInO6',
#  'Ba2CuEr2O8Pt',
#  'S20Tl2V15',
#  'Fe11Si5V4',
#  'Bi2Eu3F4S4',
#  'CaP2Rh2',
#  'Ca10Cr3Hg7Sr20',
#  'Ca3Rh8Sn26Sr3',
#  'CeCoOP',
#  'Ge5Os2',
#  'Mo3Ru2',
#  'LaPr',
#  'BCErOY',
#  'AsLaMnO',
#  'Cu3S20Se20Ta20',
#  'Cl20Cr4MnRb10',
#  'Cu9EuMg2',
#  'FeMg9O40Si10',
#  'B4C4O4Y3Yb',
#  'Ca3Co10Nd7O30',
#  'Ba2Co4O11',
#  'NaOOs',
#  'Al2ErY',
#  'Al3Dy6Si',
#  'Ag10GdLa9',
#  'La9Mn10O30Pb',
#  'Cr7Zn',
#  'Dy2La18Mn25O75Pb5',
#  'As2BiSe3',
#  'Fe2Nd2O3Se2',
#  'Ag2CGe2',
#  'C6Yb',
#  'TbTh',
#  'LaSmSn3',
#  'Cu3Mo',
#  'Br45Cs15DyYb9',
#  'Ba3K2Y2',
#  'NbNdOSr',
#  'CCuO5',
#  'GdMo6S8',
#  'BCa3Cu4O11Sr2',
#  'InIr',
#  'As5F5Fe5La2Sr3',
#  'Cu2ErO5Y',
#  'SCCO',
#  'InYb',
#  'Ce20Ni19Pt',
#  'Ru2Si2U',
#  'C2EuNOS',
#  'B20Dy5Rh20Si',
#  'O73SrTi',
#  'BCLuRe',
#  'BiLuPt',
#  'Pb3SSr8',
#  'BiSbSe2Te',
#  'Ca8Cu12Hg3O4ReSr8',
#  'BaCuFe6',
#  'HoMo6Se8',
#  'Al13Co3Ni4',
#  'H6K',
#  'Ba20CaCeCu40O80Y8',
#  'STc',
#  'Al3Ba20Cu27O71Y10',
#  'Ba2Fe3O8Y',
#  'Cu4Ge4ThU',
#  'Ce9In50LaRh10',
#  'Al3LaPd2',
#  'Fe2La7Mn8O30Pb3',
#  'Al15Ce4La',
#  'AlAsGaInSb2',
#  'Ce3La7Mn10O10',
#  'Nb25Pb28Se78',
#  'Fe4Mn3O24V6',
#  'Bi8Ca10LaPr4',
#  'O3P2V2',
#  'O3Rh',
#  'Ce3Gd15Pr22',
#  'As10Fe9Nd10O10Rh',
#  'LaMgO6ReSr',
#  'CoLa2NiO8Sr2',
#  'AuCuYb',
#  'Ba4CuOWY2',
#  'As20F3La20O17Zn20',
#  'BaBiKNaO',
#  'Al8ErMn4',
#  'Ce5La4Y',
#  'MnO6W',
#  'Ca3Cd3La7Mn10O30',
#  'P4SU5',
#  'Fe4Sb12Yb',
#  'BaCeO',
#  'BaBi2OTi2',
#  'Ba4BiO12Pb2Tl',
#  'LaP2Pd2',
#  'PBCO',
#  'Cu2GaO7Sr2Y',
#  'RhRu49Si50U25',
#  'Ca10InZr9',
#  'BaCoTb',
#  'IrO6Tb',
#  'C45F69H24N',
#  'BiCaCuOPbSbSr',
#  'BCDyFe',
#  'CFeN2',
#  'Ga3Pd2',
#  'Ca10Cu20O70Pb5Sr18Tl5Yb2',
#  'B3Ce4S',
#  'CuOSr2Tl',
#  'CaSr2',
#  'O9Pb2V3',
#  'BaOSb2Ti2',
#  'Cl2CoCu3H6O6',
#  'As12PrRu4',
#  'Mo30Pb3S40Sn2',
#  'C20H6LiN2',
#  'Bi15Pb4Sb',
#  'C2NOSSm',
#  'BaBi2OY',
#  'Ba3Ca3La14Mn20O60',
#  'OP95',
#  'CoLiO8',
#  'LaP12Ru4',
#  'BeC60Rb2',
#  'Bi4Mn7O24Sr4Ti',
#  'Ce2Fe85Lu8',
#  'BCOSm',
#  'CoIrO6',
#  'BaCu3DyOSr',
#  'Cu5KLa9O20',
#  'CeInRn',
#  'BaCo2O8V2',
#  'In3Lu',
#  'YCBCO',
#  'Al11N84Nb89O16',
#  'Bi4CeTi3',
#  'Ca3O15Ru5Sr2',
#  'IrY',
#  'BaGaSe',
#  'Mn2O7Sr2',
#  'InNd2Pt2',
#  'As10Ni8U5',
#  'Ni3S2Tl2',
#  'C20La37O80Sr3',
#  'Ca20Mn25NdO75Sm4',
#  'Ca3Cu5O10Y',
#  'EuIn2P2',
#  'B2CNi2Yb',
#  'Cu4O14PbSr4TlY2',
#  'Eu3F4',
#  'GdTh',
#  'Cu2HoO8RuSr2',
#  'C16K2Tl3',
#  'PRuZr',
#  'BaMn20O60',
#  'Bi17Cu10O10Pb3',
#  'CrLa10Mn9O30',
#  'C18CuH22N4O2',
#  'Os4P12Pr',
#  'Fe19GdMn5O40Zn5',
#  'CFe14',
#  'BaNi2O8V2',
#  'Ba25Bi5Pb26',
#  'La3P60Rh20',
#  'Dy25Ni33',
#  'H2NaPd3',
#  'As20F3Fe4La20O17Zn16',
#  'Fe10La3Mo10O60Sr17',
#  'Co2Sr3',
#  'CNd2O4U',
#  'CuGaO5',
#  'C6FeH2NaO13',
#  'Cu20Eu4La33O80Sr3',
#  'NaO4V2',
#  'As20Eu7Fe20Na3',
#  'BaCaCu3O7Pr',
#  'B5CLu5Pd20',
#  'NaNb5O',
#  'Cu3DyO8Pb2Sr2',
#  'Ir2O7',
#  'AuCeCu',
#  'BiCu2HgO2Sr4',
#  'La3Te25U5Y17',
#  'C10H32N10Ni',
#  'Ce2La3Mn10O30Sr5',
#  'C2CuN2S2',
#  'B5Ba12Cu25O70Sr8Y10',
#  'Cu2GdNbO8Sr2',
#  'Mg35Tb9Zn56',
#  'FeMnO6Sr2',
#  'Ba2HoNbO6',
#  'Al2Ba7O19Sc6',
#  'CuGeO',
#  'Ag3Si3Te14',
#  'BaCuHfO4',
#  'LaMnOSe',
#  'Ca3La6Mn9NdO30Sr3',
#  'BaMo6S8',
#  'Ce3CuFeO9SrY3',
#  'B2CPrPt2',
#  'BiO3',
#  'IrNd3O7',
#  'Eu7La7Mn20O60Pb6',
#  'RhSnYb',
#  'Fe5STe4',
#  'CFeMnO9Sr4',
#  'Al5Co13O7',
#  'Co9Cr20NiO40',
#  'CrMn4O15',
#  'FeLaSr',
#  'Ba5Fe19K5',
#  'Bi27S77Ta25',
#  'B2C2Dy11',
#  'Bi17Cu30O10Pb3Sr20',
#  'Ba2PrRu',
#  'CCrFeP',
#  'HgPb2',
#  'CaF12P2',
#  'Cd20LaPt2',
#  'Ce50Si93',
#  'O7Sb',
#  'B39CMg19Ti',
#  'Gd7Y3',
#  'C40Co17Ni3Tb20',
#  'H11La4',
#  'CeGa5La4Pt5',
#  'In2SnY',
#  'CeGaNi4',
#  'Cr10Fe21O48',
#  'Ce60Ni',
#  'CeCoSi2',
#  'B2CoCu2O6',
#  'B2CNi2Tm',
#  'MnNdOSr',
#  'Mo12Se15Tl2',
#  'Bi9Pb41',
#  'RuY',
#  'Ca2Mn25Nd23O75',
#  'La3Nd',
#  'B2CeOs3',
#  'GdGeRh',
#  'Dy6Fe16O',
#  'Co10Eu2Nd3P10',
#  'Os4P12Y',
#  'Cu2S2Sr',
#  'CaMo6S8',
#  'Ce37La3Ru80Si80',
#  'Cl3CoTl',
#  'Cl12H10Ni5O5',
#  'CrLa3Mn5O15Sr',
#  'C4Cl8CuH24MnN4',
#  'Al12Pr3Ru4',
#  'As10CoFe9Nd10O10',
#  'Ba2CCuO5',
#  'Er5Ge10Ir4',
#  'Eu3La10Mn20O60Sr7',
#  'Ca2CuMnNdO6',
#  'CeCu4O20Ru2Sr4Y3',
#  'BaCuP',
#  'BaDy',
#  'Eu2H5Ir',
#  'Ce3Cu10O50Ru5Sr10',
#  'Ba3NaO9Ru2',
#  'B2CPd2Pr',
#  'HoTiY',
#  'O25Sr8V8',
#  'GdLa6Mn8O30Si2Sr3',
#  'Ga18La19Mg2O60Sr',
#  'Pb2ReSr2',
#  'Ca4La5Mn10O30Te',
#  'Bi5Ca2O15Sm3',
#  'IrZn10',
#  'P2Pd2Yb',
#  'Cr10Cu10Fe7Ga3O40',
#  'AsFeHLaO',
#  'CuO4Pr2',
#  'CoCu2O7Sr2',
#  'CeCu4Nb2O20Sr4Y3',
#  'Ca20Na',
#  'Co3Ni17Si4Y2',
#  'H6O7Tc',
#  'Co10La3O20',
#  'DyFe4P12',
#  'Ag5O6Pb2',
#  'AgCeSb',
#  'Gd30Sc3Y7',
#  'Ce4PdPt3Sn4',
#  'InPu',
#  'Ce3Cu20Gd37O80',
#  'Cr11Fe65Ni24',
#  'C2Co5H16N3O16',
#  'La2Mn10Nd5O30Sr3',
#  'CCOC',
#  'Ge4La3Pd4',
#  'Ce5PdRh4Sb5',
#  'CoMgO8',
#  'B7Fe8Ni31Si4',
#  'In5IrSm',
#  'C36Cl4H80MnN2',
#  'Co3Sb4U3',
#  'Fe2GdSi2',
#  'Ba10Ce9Cu9Fe11Nd10O70',
#  'Ce5Ge2Pd',
#  'Gd17Ge40Mn40Pr3',
#  'MnPbS',
#  'InSm2',
#  'Nb5S16Sn6',
#  'Cd10Cr19InSe40',
#  'LaO4SrTi',
#  'CoF4',
#  'Be13La',
#  'Co3Gd20Ni17',
#  'AlNU',
#  'CrGe3La',
#  'Cl7Hf10N10',
#  'C60CaK2',
#  'As40Co3Fe37Sr20',
#  'InSn4Te5',
#  'FO5Ta2Tl',
#  'Ca4La5',
#  'CeSbV',
#  'Pt3Sb4U3',
#  'Ce10CuPd29',
#  ...]

# %%
def sc_group_distance(index):
    return distance.euclidean(embeddings_in_2d[index], embeddings_in_2d[words.index('BSCCO')])

# %%
distance_reference = sc_group_distance(words.index('YBCO'))

# %%
plt.figure(figsize = (16,9))
for i in range(len(embeddings_in_2d)):
    x = embeddings_in_2d[i][0]
    y = embeddings_in_2d[i][1]
    plt.scatter(x, y, color = greys(high_tc_similarity[i]) )
    if words[i] in filtered_candidates and distance.euclidean(embeddings_in_2d[i], embeddings_in_2d['BSCCO']) > 5*distance_reference:
        plt.annotate(words[i], alpha=0.8, xy = (x,y), xytext = (5,2), weight = 'bold', textcoords="offset points")
plt.title("T-SNE Visualization of Chemical Symbol Representations, Perplexity = 10")
plt.show()
# Out:
#   File "<ipython-input-44-74cb8263b35e>", line 6
#     if words[i] in filtered_candidates and
#                                            ^
# SyntaxError: invalid syntax
